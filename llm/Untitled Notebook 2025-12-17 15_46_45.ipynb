# %%
from file_parser import parse_files_to_single_text

file_uris = [
    "https://costestimatorstorage.blob.core.windows.net/finops-output/uploads/pdfs/assumed-cost.pdf"
]

final_text = parse_files_to_single_text(file_uris)
print(final_text)

# %%
# %restart_python

# %%
spark.conf.get("spark.databricks.clusterUsageTags.sparkVersion")
